# %%
import pandas as pd

# %%
df = pd.read_csv('../data/rawDataGmaps.csv')

# Exibir as primeiras linhas do DataFrame para garantir que foi carregado corretamente
df.head()
# Out:
#   origem          destino  total_duration_min  custo  custo_passeio  \
# 0  Hotel  Cristo Redentor           79.016667    4.3          128.0
# 1  Hotel  Jardim Botânico           48.083333    4.3           23.0
# 2  Hotel             CCBB           19.683333    0.0            0.0
# 3  Hotel  Museu do Amanhã           31.466667    0.0           30.0
# 4  Hotel    Pão de Açúcar           47.500000    7.5          195.0
#
#    tempo_passeio_min  score_passeio
# 0               90.0           0.01
# 1              105.0           0.20
# 2              150.0           0.25
# 3               90.0           0.15
# 4               60.0           0.05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   origem              210 non-null    object
#  1   destino             210 non-null    object
#  2   total_duration_min  210 non-null    float64
#  3   custo               210 non-null    float64
#  4   custo_passeio       210 non-null    float64
#  5   tempo_passeio_min   210 non-null    float64
#  6   score_passeio       210 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 11.6+ KB

# %%
df.describe()
# Out:
#        total_duration_min       custo  custo_passeio  tempo_passeio_min  \
# count          210.000000  210.000000     210.000000         210.000000
# mean            60.894365    4.760000      51.100000          75.333333
# std             30.915372    3.132561      55.330822          45.069148
# min              3.616667    0.000000       0.000000           0.000000
# 25%             37.079167    4.300000       6.000000          45.000000
# 50%             60.858333    4.300000      30.000000          90.000000
# 75%             83.845833    8.600000      75.000000         105.000000
# max            149.150000   12.900000     195.000000         150.000000
#
#        score_passeio
# count     210.000000
# mean        0.170667
# std         0.098789
# min         0.000000
# 25%         0.100000
# 50%         0.200000
# 75%         0.250000
# max         0.300000

# %%
df.describe(include='object')
# Out:
#        origem          destino
# count     210              210
# unique     15               15
# top     Hotel  Cristo Redentor
# freq       14               14

# %%
df_restaurante_spesso = df[df['destino'] == 'Restaurante Spesso']
df_restaurante_spesso
# Out:
#                     origem             destino  total_duration_min  custo  \
# 13                   Hotel  Restaurante Spesso           18.316667    7.5
# 27         Cristo Redentor  Restaurante Spesso           48.000000    0.0
# 41         Jardim Botânico  Restaurante Spesso           34.716667    4.3
# 55                    CCBB  Restaurante Spesso           45.616667    4.3
# 69         Museu do Amanhã  Restaurante Spesso           59.150000    8.6
# 83           Pão de Açúcar  Restaurante Spesso           29.383333    0.0
# 97                 AquaRio  Restaurante Spesso           47.000000    8.6
# 111      Theatro Municipal  Restaurante Spesso           20.000000    7.5
# 125      Parque dos Patins  Restaurante Spesso           48.750000    4.3
# 139  Mosteiro de São Bento  Restaurante Spesso           51.783333    4.3
# 153           Santa Teresa  Restaurante Spesso           22.300000    7.5
# 167    Forte de Copacabana  Restaurante Spesso           48.783333    4.3
# ...

# %%
# Criando a coluna 'custo_total' como a soma de 'custo' e 'custo_passeio'
df['custo_total'] = df['custo'] + df['custo_passeio']

# Criando a coluna 'tempo_total' como a soma de 'total_duration_min' e 'tempo_passeio_min'
df['tempo_total'] = df['total_duration_min'] + df['tempo_passeio_min']

# Exibindo o DataFrame atualizado
df
# Out:
#                  origem                destino  total_duration_min  custo  \
# 0                 Hotel        Cristo Redentor           79.016667    4.3
# 1                 Hotel        Jardim Botânico           48.083333    4.3
# 2                 Hotel                   CCBB           19.683333    0.0
# 3                 Hotel        Museu do Amanhã           31.466667    0.0
# 4                 Hotel          Pão de Açúcar           47.500000    7.5
# ..                  ...                    ...                 ...    ...
# 205  Restaurante Spesso  Mosteiro de São Bento           45.333333    4.3
# 206  Restaurante Spesso           Santa Teresa           44.166667    4.3
# 207  Restaurante Spesso    Forte de Copacabana           56.616667    4.3
# 208  Restaurante Spesso       BioParque do Rio           60.666667    8.6
# 209  Restaurante Spesso               Maracanã           86.433333    4.3
#
#      custo_passeio  tempo_passeio_min  score_passeio  custo_total  tempo_total
# ...

# %%
df.sample(10, random_state=1)
# Out:
#                   origem                destino  total_duration_min  custo  \
# 44                  CCBB        Jardim Botânico           55.616667    4.3
# 188             Maracanã                AquaRio           75.150000    8.6
# 51                  CCBB           Santa Teresa           18.833333    0.0
# 204   Restaurante Spesso      Parque dos Patins           45.366667    4.3
# 35       Jardim Botânico      Parque dos Patins           23.100000    0.0
# 89               AquaRio          Pão de Açúcar           91.400000    8.6
# 33       Jardim Botânico                AquaRio           70.200000    8.6
# 167  Forte de Copacabana     Restaurante Spesso           48.783333    4.3
# 205   Restaurante Spesso  Mosteiro de São Bento           45.333333    4.3
# 168     BioParque do Rio                  Hotel           50.850000    4.3
#
#      custo_passeio  tempo_passeio_min  score_passeio  custo_total  tempo_total
# ...

# %%
df_tour = df.drop(['total_duration_min', 'tempo_passeio_min', 'custo', 'custo_passeio'], axis=1)
df_tour
# Out:
#                  origem                destino  score_passeio  custo_total  \
# 0                 Hotel        Cristo Redentor           0.01        132.3
# 1                 Hotel        Jardim Botânico           0.20         27.3
# 2                 Hotel                   CCBB           0.25          0.0
# 3                 Hotel        Museu do Amanhã           0.15         30.0
# 4                 Hotel          Pão de Açúcar           0.05        202.5
# ..                  ...                    ...            ...          ...
# 205  Restaurante Spesso  Mosteiro de São Bento           0.30          4.3
# 206  Restaurante Spesso           Santa Teresa           0.10         24.3
# 207  Restaurante Spesso    Forte de Copacabana           0.20         10.3
# 208  Restaurante Spesso       BioParque do Rio           0.30         60.2
# 209  Restaurante Spesso               Maracanã           0.25         79.3
#
#      tempo_total
# 0     169.016667
# 1     153.083333
# ...

# %%
df_tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   origem         210 non-null    object
#  1   destino        210 non-null    object
#  2   score_passeio  210 non-null    float64
#  3   custo_total    210 non-null    float64
#  4   tempo_total    210 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 8.3+ KB

# %%
df_tour.to_csv('../data/data.csv', index=False)
